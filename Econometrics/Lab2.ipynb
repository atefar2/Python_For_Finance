# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from scipy.stats import t
from statsmodels.stats.outliers_influence import summary_table

# %% [markdown]
# # Data loading
# Я обрав компанію Goldman Sachs.

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
data_gs = pd.read_csv('GS.csv', parse_dates=['Date'], index_col='Date',date_parser=dateparse)
data_sp500 = pd.read_csv('^GSPC.csv', parse_dates=['Date'], index_col='Date',date_parser=dateparse)

target = ((data_gs['High'] + data_gs['Low']) / 2.).values
x = ((data_sp500['High'] + data_sp500['Low'])/2.).values

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target, label='target')
plt.plot(x, label='x')
plt.legend()

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.show();

# %% [markdown]
# # Model comparison

# %% [markdown]
# ### Model parameters

# %%
class Model:
    def __init__(self, x, y):
        self.n = x.shape[0]
        self.x = x
        self.x_mean = self.x.mean()
        self.x_std = self.x.std()
        
        self.y = y
        self.y_mean = self.y.mean()
        self.y_std = self.y.std()
        
        self.alpha, self.beta = self.param_eval()
    
    def predict(self, x, confidence = False):
        preds = list()
        for i in range(self.n):
            res = self.alpha + self.beta * x[i]
            preds.append(res)
        return np.array(preds)
    
    def R_squared(self):
        corr_coef = np.corrcoef(self.x, self.y)
        return corr_coef[0][1] ** 2
    
    def param_eval(self):
        beta = sum((self.x - self.x_mean) * (self.y - self.y_mean)) / (self.n * self.x_std ** 2)
        alpha = self.y_mean - beta * self.x_mean
        return alpha, beta
    
    def F_statistic(self):
        y_hat = self.predict(self.x)
        f_stat = (self.n - 2) * sum((y_hat - self.y_mean) ** 2) / (sum ((self.y - y_hat) ** 2))
        return f_stat
    
    def parameters(self):
        return self.alpha, self.beta

# %% [markdown]
# ## Model 1: $y = \alpha * \beta ^{x} $
# $y = \alpha * \beta ^{x} $    ==>   $ln(y) = ln(\alpha) + ln(\beta) * x $

# %%
model = Model(x, np.log(target))
alpha, beta = model.parameters()
y_hat = np.exp(model.predict(x))

print('Parameters: ')
print(f'alpha: {np.round(np.exp(alpha), 4)}  beta: {np.round(np.exp(beta), 4)}')
print('==========='* 5)
print(f'R_squared: {np.round(model.R_squared(), 5)}  r: {np.round(np.sqrt(model.R_squared()), 5)}  f_statistic: {np.round(model.F_statistic(), 5)}')
print('')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target)
plt.plot(y_hat)

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.scatter(x, y_hat)
plt.show();
# Out:
# Parameters:
# alpha: 65.6043  beta: 1.0005
# =======================================================
# R_squared: 0.52555  r: 0.72495  f_statistic: 274.70675

# %% [markdown]
# ### Model 2: $y = \alpha * e ^{\beta x}$
# $y = \alpha * e ^{\beta x}$  ==>  $ln(y) = ln(\alpha) + \beta * x$

# %%
model = Model(x, np.log(target))
alpha, beta = model.parameters()
y_hat = np.exp(model.predict(x))

print('Parameters: ')
print(f'alpha: {np.round(np.exp(alpha), 4)}  beta: {np.round(beta, 4)}')
print('==========='* 5)
print(f'R_squared: {np.round(model.R_squared(), 5)}  r: {np.round(np.sqrt(model.R_squared()), 5)}  f_statistic: {np.round(model.F_statistic(), 5)}')
print('')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target)
plt.plot(y_hat)

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.scatter(x, y_hat)
plt.show();
# Out:
# Parameters:
# alpha: 65.6043  beta: 0.0005
# =======================================================
# R_squared: 0.52555  r: 0.72495  f_statistic: 274.70675

# %% [markdown]
# ### Model 3:$y = e ^{\alpha  + \beta x}$
# $y = e ^{\alpha  + \beta x}$  ==>  $ln(y) = \alpha + \beta * x$

# %%
model = Model(x, np.log(target))
alpha, beta = model.parameters()
y_hat = np.exp(model.predict(x))

print('Parameters: ')
print(f'alpha: {np.round(alpha, 4)}  beta: {np.round(beta, 4)}')
print('==========='* 5)
print(f'R_squared: {np.round(model.R_squared(), 5)}  r: {np.round(np.sqrt(model.R_squared()), 5)}  f_statistic: {np.round(model.F_statistic(), 5)}')
print('')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target)
plt.plot(y_hat)

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.scatter(x, y_hat)
plt.show();
# Out:
# Parameters:
# alpha: 4.1836  beta: 0.0005
# =======================================================
# R_squared: 0.52555  r: 0.72495  f_statistic: 274.70675

# %% [markdown]
# ### Model 4: $y = 10 ^{\alpha  + \beta x}$
# $y = 10 ^{\alpha  + \beta * x}$  ==>  $ln_{10}(y) = \alpha + \beta * x$

# %%
model = Model(x, np.log10(target))
alpha, beta = model.parameters()
y_hat = 10 ** (model.predict(x))

print('Parameters: ')
print(f'alpha: {np.round(alpha, 4)}  beta: {np.round(beta, 4)}')
print('==========='* 5)
print(f'R_squared: {np.round(model.R_squared(), 5)}  r: {np.round(np.sqrt(model.R_squared()), 5)}  f_statistic: {np.round(model.F_statistic(), 5)}')
print('')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target)
plt.plot(y_hat)

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.scatter(x, y_hat)
plt.show();
# Out:
# Parameters:
# alpha: 1.8169  beta: 0.0002
# =======================================================
# R_squared: 0.52555  r: 0.72495  f_statistic: 274.70675

# %% [markdown]
# ### Model 5: $y = \alpha * x ^{\beta}$
# $y = \alpha * x ^{\beta}$  ==>  $ln(y) = ln(\alpha) + \beta * ln(x)$

# %%
model = Model(np.log(x), np.log(target))
alpha, beta = model.parameters()
y_hat = np.exp(model.predict(np.log(x)))

print('Parameters: ')
print(f'alpha: {np.round(alpha, 4)}  beta: {np.round(beta, 4)}')
print('==========='* 5)
print(f'R_squared: {np.round(model.R_squared(), 5)}  r: {np.round(np.sqrt(model.R_squared()), 5)}  f_statistic: {np.round(model.F_statistic(), 5)}')
print('')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target)
plt.plot(y_hat)

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.scatter(x, y_hat)
plt.show();
# Out:
# Parameters:
# alpha: -1.1285  beta: 0.8285
# =======================================================
# R_squared: 0.56066  r: 0.74877  f_statistic: 316.4853

# %% [markdown]
# ### Model 6: $y = \alpha + \beta * \frac{1}{x}$
# $y = \alpha + \beta * \frac{1}{x}$  ==>  $y = \alpha + \beta * x_{new}$, where $x_{new} = \frac{1}{x} $

# %%
model = Model(1 / x, target)
alpha, beta = model.parameters()
y_hat = model.predict(1 / x)

print('Parameters: ')
print(f'alpha: {np.round(alpha, 4)}  beta: {np.round(beta, 4)}')
print('==========='* 5)
print(f'R_squared: {np.round(model.R_squared(), 5)}  r: {np.round(np.sqrt(model.R_squared()), 5)}  f_statistic: {np.round(model.F_statistic(), 5)}')
print('')

plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
plt.plot(target)
plt.plot(y_hat)

plt.subplot(1, 2, 2)
plt.scatter(x, target)
plt.scatter(x, y_hat)
plt.show();
# Out:
# Parameters:
# alpha: 273.9228  beta: -178094.3372
# =======================================================
# R_squared: 0.58341  r: 0.76381  f_statistic: 347.30504

# %% [markdown]
# From experiments above we can see that $y = \alpha + \beta * \frac{1}{x}$ model (__model 6__) performs the best with correlation coefficient of 0.76 , $R^{2}$ of 0.58 and F-statistic of 347. All of these values are the best among all the models. Therefore we are taking this model for further exploration

# %% [markdown]
# # Model analysis

# %%
import statsmodels.api as sm
X = sm.add_constant(1 / x)
model = sm.OLS(target, X)
lin = model.fit()
lin.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.583
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     347.3
# Date:                Sat, 11 Apr 2020   Prob (F-statistic):           4.62e-49
# Time:                        11:49:51   Log-Likelihood:                -1236.0
# No. Observations:                 250   AIC:                             2476.
# Df Residuals:                     248   BIC:                             2483.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        273.9228      7.160     38.256      0.000     259.820     288.026
# x1         -1.781e+05   9556.405    -18.636      0.000   -1.97e+05   -1.59e+05
# ==============================================================================
# Omnibus:                        3.695   Durbin-Watson:                   0.063
# Prob(Omnibus):                  0.158   Jarque-Bera (JB):                2.962
# Skew:                           0.150   Prob(JB):                        0.227
# Kurtosis:                       2.560   Cond. No.                     4.43e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.43e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Hypothesis testing  $\alpha$ = 0
# $H_0: \alpha = 0 $ <br>
# $H_1: \alpha \ne 0 $ <br>
# From the second table above in the __const__ row we can see that obtained t-test results are equal to 38.256 and corresponding p-value is 0.000. As obtained p-value is below 0.05 it means that the variable is significant . Therefore, the $\alpha$ is most probably different from 0. Lets check whether given confidence intervals in the table are true.

# %%
upper_bound = lin.params[0] + t.ppf(1-0.025, 250) * lin.bse[0]
lower_bound = lin.params[0] - t.ppf(1-0.025, 250) * lin.bse[0]
print('Alpha Upper_bound: ',upper_bound, ' Lower bound: ', lower_bound)
# Out:
# Alpha Upper_bound:  288.0250193999783  Lower bound:  259.8205971353467

# %% [markdown]
# ### Hypothesis testing  $\beta$ = 0
# $H_0: \beta = 0 $ <br>
# $H_1: \beta \ne 0 $ <br>
# From the second table above in the __x1__ row we can see that obtained t-test results are equal to -18.976 and corresponding p-value is 0.000. As obtained p-value is below 0.05 it means that the variable is significant . Therefore, the $\beta$ is most probably different from 0. Lets check whether given confidence intervals in the table are true.

# %%
upper_bound = lin.params[1] + t.ppf(1-0.025, 250) * lin.bse[1]
lower_bound = lin.params[1] - t.ppf(1-0.025, 250) * lin.bse[1]
print('Beta Upper_bound: ',upper_bound, ' Lower bound: ', lower_bound)
# Out:
# Beta Upper_bound:  -159273.01208766332  Lower bound:  -196915.66227109943

# %% [markdown]
# ### F-statistic
# $H_0: \beta_1 ... \beta_n = 0 $  (if all $\beta$s are 0, then none of the independent variables matter. Therefore, our model has no merit)<br>
# $H_1$: at least one $\beta$ from $\beta_1 ... \beta_n \ne 0 $ <br>
#
# In our case, F-statistic is 347.3 with a p-value of close to 0.000. We can say that the overall model is significant. One thing worth mentioning is, the lower the F-statistic, the closest model to be non-significant.

# %% [markdown]
# ### Predictions with 95% confidence intervals

# %%
yprd_ci_lower, yprd_ci_upper = summary_table(lin, alpha = 0.05)[1][:, 4:6].T

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, target, linestyle = "None", marker = "o", label = "actual", markerfacecolor = "None", color = "blue")
plt.plot(x, y_hat, color = "red", label = "OLS")
plt.plot(x, yprd_ci_lower, color = "green", linestyle = "--", label = "Confidence Interval")
plt.plot(x, yprd_ci_upper, color = "green", linestyle = "--")
plt.legend()
plt.show();

# %% [markdown]
# # Forecast

# %%
x_mat = np.array([1, x[-1] * 1.2])

dt = lin.get_prediction(1 / x_mat).summary_frame(alpha = 0.05)
y_prd = dt['mean']
y_prd_ci_lower = dt['obs_ci_lower']
y_prd_ci_upper = dt['obs_ci_upper']

print(f'x = {x_mat[1]} y_hat = {y_prd[0]}')
print(f'y confidence intervals: ({y_prd_ci_lower[0]}, {y_prd_ci_upper[0]})')
# Out:
# x = 3917.2259766 y_hat = 228.45840610060645
# y confidence intervals: (160.62474492356128, 296.29206727765165)

# %%
plt.figure(figsize=(8, 6))
plt.plot(x, target, linestyle = "None", marker = "o", label = "actual", markerfacecolor = "None", color = "blue")
plt.plot(x, y_hat, color = "red", label = "OLS")
plt.plot(x, yprd_ci_lower, color = "green", linestyle = "--", label = "Confidence Interval")
plt.plot(x, yprd_ci_upper, color = "green", linestyle = "--")
plt.plot([x_mat[-1]], [y_prd[0]], marker='o', color='k', label='forecasting')
plt.plot([x_mat[-1]], [y_prd_ci_lower[0]], marker='o', markerfacecolor = "None", color='k', label='forecasting_conf_int')
plt.plot([x_mat[-1]], [y_prd_ci_upper[0]], marker='o', markerfacecolor = "None", color='k', label='forecasting_conf_int')
plt.legend()
plt.show();
